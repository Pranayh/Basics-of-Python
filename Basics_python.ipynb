# %% [markdown]
# ## **Hello world**

# %%
print("HEllo world")
# Out:
# HEllo world

# %% [markdown]
# **Taking Input from the user**

# %%
print("checking the paisant in hospital")
name = input("What is your name bro? ")
age = input("what is your age bhau? ")
print("hello " + name)
print("ur current age is "  + age + " Years")
# Out:
# checking the paisant in hospital
# What is your name bro? p
# what is your age bhau? 3
# hello p
# ur current age is 3 Years

# %% [markdown]
# **Exercise**

# %%
print("ENter the two numbers: ")
a=int(input("First No.: "))
b=int(input("Second No.: ")) # how to take an input from the user , favorable datatype

c=a+b
print(c)
print("Addition of two Numbers: " + str(c)) #how to change the datatype of variable
# Out:
# ENter the two numbers:
# First No.: 2
# Second No.: 3
# 5
# Addition of two Numbers: 5

# %% [markdown]
# # **Data type Conversion**

# %%
# type canversion

a=input("First No.: ")
b=input("Second No.: ")
sum= float(a)+float(b)

print("Sum is: " + str(sum))
# Out:
# First No.: 2
# Second No.: 4
# Sum is: 6.0

# %% [markdown]
# ### ***String***

# %%
course ="my name is pranay"

print(course.upper()) #upper() capitalize all worlds and print new string , never change previous one
print(course) # In python string is inmutable, so we can't change the original string, always create new string
# Out:
# MY NAME IS PRANAY
# my name is pranay

# %% [markdown]
# **Some string operation**

# %%
course ="my name is pranay"
course.rfind("is")
# Out:
# 8

# %%
course.replace("my" , "your")
# Out:
# 'your name is pranay'

# %%
print("name" in course)
# Out:
# True
